# %%
print("hello worl")
# Out:
# hello worl

# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 import seaborn as sns
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
import numpy as np
# Out:
# ...
#   WARNING: The script f2py.exe is installed in 'c:\Users\hp\AppData\Local\Programs\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 20.2.3; however, version 23.0 is available.
# You should consider upgrading via the 'c:\Users\hp\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
data = pd.read_csv("C:/Users/hp/Desktop/python folder/IT Salary Survey EU  2020 (1).csv")

# %%
#understanding the data

# %%
data.head()
# Out:
#           Timestamp   Age Gender    City           Position   \
# 0  24/11/2020 11:14  26.0   Male  Munich   Software Engineer
# 1  24/11/2020 11:14  26.0   Male  Berlin   Backend Developer
# 2  24/11/2020 11:14  29.0   Male  Berlin   Software Engineer
# 3  24/11/2020 11:15  28.0   Male  Berlin  Frontend Developer
# 4  24/11/2020 11:15  37.0   Male  Berlin   Backend Developer
#
#   Total years of experience Years of experience in Germany Seniority level  \
# 0                         5                              3          Senior
# 1                         7                              4          Senior
# 2                        12                              6            Lead
# 3                         4                              1          Junior
# 4                        17                              6          Senior
#
#   Your main technology / programming language  \
# 0                                  TypeScript
# 1                                        Ruby
# ...

# %%
data.tail()
# Out:
#              Timestamp   Age Gender         City  \
# 1248  18/01/2021 15:05  31.0   Male       Berlin
# 1249  18/01/2021 17:46  33.0   Male       Berlin
# 1250  18/01/2021 23:20  39.0   Male       Munich
# 1251  19/01/2021 10:17  26.0   Male  Saarbrücken
# 1252  19/01/2021 12:01  26.0   Male       Berlin
#
#                                    Position  Total years of experience  \
# 1248                       Backend Developer                         9
# 1249  Researcher/ Consumer Insights Analyst                         10
# 1250                   IT Operations Manager                        15
# 1251                      Frontend Developer                         7
# 1252                                  DevOps                         2
#
#      Years of experience in Germany Seniority level  \
# 1248                              5          Senior
# 1249                            1.5          Senior
# 1250                              2            Lead
# ...

# %%
data.shape
# Out:
# (1253, 23)

# %%
data.describe()
# Out:
#                Age  Yearly brutto salary (without bonus and stocks) in EUR  \
# count  1226.000000                                       1.253000e+03
# mean     32.509788                                       8.027904e+07
# std       5.663804                                       2.825061e+09
# min      20.000000                                       1.000100e+04
# 25%      29.000000                                       5.880000e+04
# 50%      32.000000                                       7.000000e+04
# 75%      35.000000                                       8.000000e+04
# max      69.000000                                       1.000000e+11
#
#        Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country  \
# count                                       8.850000e+02
# mean                                        6.322459e+05
# std                                         1.680508e+07
# ...

# %%
data.columns
# Out:
# Index(['Timestamp', 'Age', 'Gender', 'City', 'Position ',
#        'Total years of experience', 'Years of experience in Germany',
#        'Seniority level', 'Your main technology / programming language',
#        'Other technologies/programming languages you use often',
#        'Yearly brutto salary (without bonus and stocks) in EUR',
#        'Yearly bonus + stocks in EUR',
#        'Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country',
#        'Annual bonus+stocks one year ago. Only answer if staying in same country',
#        'Number of vacation days', 'Employment status', 'Сontract duration',
#        'Main language at work', 'Company size', 'Company type',
#        'Have you lost your job due to the coronavirus outbreak?',
#        'Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week',
# ...

# %%
data.nunique()
# Out:
# Timestamp                                                                                                                  1026
# Age                                                                                                                          40
# Gender                                                                                                                        3
# City                                                                                                                        119
# Position                                                                                                                    148
# Total years of experience                                                                                                    48
# Years of experience in Germany                                                                                               53
# ...

# %%
data['Age'].unique()
# Out:
# array([26., 29., 28., 37., 32., 24., 35., nan, 34., 31., 41., 27., 25.,
#        59., 36., 38., 40., 39., 33., 30., 49., 48., 44., 66., 45., 43.,
#        42., 46., 47., 56., 53., 65., 22., 23., 50., 51., 21., 20., 54.,
#        69., 52.])

# %%
#cleaning data

# %%
data.isnull().sum()
# Out:
# Timestamp                                                                                                                    0
# Age                                                                                                                         27
# Gender                                                                                                                      10
# City                                                                                                                         0
# Position                                                                                                                     6
# Total years of experience                                                                                                   16
# Years of experience in Germany                                                                                              32
# ...

# %%
import os

# %%
df = pd.read_csv("C:/Users/hp/Desktop/python folder/IT Salary Survey EU  2020 (1).csv")

# %%
df
# Out:
#              Timestamp   Age Gender         City  \
# 0     24/11/2020 11:14  26.0   Male       Munich
# 1     24/11/2020 11:14  26.0   Male       Berlin
# 2     24/11/2020 11:14  29.0   Male       Berlin
# 3     24/11/2020 11:15  28.0   Male       Berlin
# 4     24/11/2020 11:15  37.0   Male       Berlin
# ...                ...   ...    ...          ...
# 1248  18/01/2021 15:05  31.0   Male       Berlin
# 1249  18/01/2021 17:46  33.0   Male       Berlin
# 1250  18/01/2021 23:20  39.0   Male       Munich
# 1251  19/01/2021 10:17  26.0   Male  Saarbrücken
# 1252  19/01/2021 12:01  26.0   Male       Berlin
#
#                                    Position  Total years of experience  \
# 0                          Software Engineer                         5
# 1                          Backend Developer                         7
# 2                          Software Engineer                        12
# 3                         Frontend Developer                         4
# ...

# %%
# detecting and cleaning of data

# %%
import pandas as pd

# %%
missing_value = ["NaN"]
df = pd.read_csv("C:/Users/hp/Desktop/python folder/IT Salary Survey EU  2020 (1).csv",na_values=missing_value)

# %%
df.isnull().sum()
# Out:
# Timestamp                                                                                                                    0
# Age                                                                                                                         27
# Gender                                                                                                                      10
# City                                                                                                                         0
# Position                                                                                                                     6
# Total years of experience                                                                                                   16
# Years of experience in Germany                                                                                              32
# ...

# %%
df.isnull().any()
# Out:
# Timestamp                                                                                                                  False
# Age                                                                                                                         True
# Gender                                                                                                                      True
# City                                                                                                                       False
# Position                                                                                                                    True
# Total years of experience                                                                                                   True
# Years of experience in Germany                                                                                              True
# ...

# %%
 pip install seaborn
# Out:
# ...
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'c:\Users\hp\AppData\Local\Programs\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 20.2.3; however, version 23.0 is available.
# You should consider upgrading via the 'c:\Users\hp\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(df.isnull(), annot=True)
# Out:
# <Axes: >

# %%
df.dropna()
# Out:
#              Timestamp   Age  Gender        City             Position   \
# 35    24/11/2020 11:28  33.0    Male      Berlin        Data Scientist
# 141   24/11/2020 12:09  34.0    Male      Munich       Cloud Architect
# 221   24/11/2020 13:33  32.0    Male   Stuttgart           QA Engineer
# 225   24/11/2020 13:37  24.0    Male  Boeblingen  C/C++/Java developer
# 276   24/11/2020 14:58  38.0    Male      Munich     Backend Developer
# ...                ...   ...     ...         ...                   ...
# 1228  07/01/2021 10:47  28.0    Male      Munich     Software Engineer
# 1233  08/01/2021 17:23  33.0  Female      Munich           Testmanager
# 1236  11/01/2021 12:12  39.0    Male      Berlin           QA Engineer
# 1237  12/01/2021 12:48  37.0    Male      Berlin      Mobile Developer
# 1252  19/01/2021 12:01  26.0    Male      Berlin                DevOps
#
#      Total years of experience Years of experience in Germany Seniority level  \
# ...

# %%
df.interpolate()
# Out:
#              Timestamp   Age Gender         City  \
# 0     24/11/2020 11:14  26.0   Male       Munich
# 1     24/11/2020 11:14  26.0   Male       Berlin
# 2     24/11/2020 11:14  29.0   Male       Berlin
# 3     24/11/2020 11:15  28.0   Male       Berlin
# 4     24/11/2020 11:15  37.0   Male       Berlin
# ...                ...   ...    ...          ...
# 1248  18/01/2021 15:05  31.0   Male       Berlin
# 1249  18/01/2021 17:46  33.0   Male       Berlin
# 1250  18/01/2021 23:20  39.0   Male       Munich
# 1251  19/01/2021 10:17  26.0   Male  Saarbrücken
# 1252  19/01/2021 12:01  26.0   Male       Berlin
#
#                                    Position  Total years of experience  \
# 0                          Software Engineer                         5
# 1                          Backend Developer                         7
# 2                          Software Engineer                        12
# 3                         Frontend Developer                         4
# ...

# %%
df.fillna(0)
# Out:
#              Timestamp   Age Gender         City  \
# 0     24/11/2020 11:14  26.0   Male       Munich
# 1     24/11/2020 11:14  26.0   Male       Berlin
# 2     24/11/2020 11:14  29.0   Male       Berlin
# 3     24/11/2020 11:15  28.0   Male       Berlin
# 4     24/11/2020 11:15  37.0   Male       Berlin
# ...                ...   ...    ...          ...
# 1248  18/01/2021 15:05  31.0   Male       Berlin
# 1249  18/01/2021 17:46  33.0   Male       Berlin
# 1250  18/01/2021 23:20  39.0   Male       Munich
# 1251  19/01/2021 10:17  26.0   Male  Saarbrücken
# 1252  19/01/2021 12:01  26.0   Male       Berlin
#
#                                    Position  Total years of experience  \
# 0                          Software Engineer                         5
# 1                          Backend Developer                         7
# 2                          Software Engineer                        12
# 3                         Frontend Developer                         4
# ...

# %%
df.head()
# Out:
#           Timestamp   Age Gender    City           Position   \
# 0  24/11/2020 11:14  26.0   Male  Munich   Software Engineer
# 1  24/11/2020 11:14  26.0   Male  Berlin   Backend Developer
# 2  24/11/2020 11:14  29.0   Male  Berlin   Software Engineer
# 3  24/11/2020 11:15  28.0   Male  Berlin  Frontend Developer
# 4  24/11/2020 11:15  37.0   Male  Berlin   Backend Developer
#
#   Total years of experience Years of experience in Germany Seniority level  \
# 0                         5                              3          Senior
# 1                         7                              4          Senior
# 2                        12                              6            Lead
# 3                         4                              1          Junior
# 4                        17                              6          Senior
#
#   Your main technology / programming language  \
# 0                                  TypeScript
# 1                                        Ruby
# ...

# %%
df.fillna(0)
# Out:
#              Timestamp   Age Gender         City  \
# 0     24/11/2020 11:14  26.0   Male       Munich
# 1     24/11/2020 11:14  26.0   Male       Berlin
# 2     24/11/2020 11:14  29.0   Male       Berlin
# 3     24/11/2020 11:15  28.0   Male       Berlin
# 4     24/11/2020 11:15  37.0   Male       Berlin
# ...                ...   ...    ...          ...
# 1248  18/01/2021 15:05  31.0   Male       Berlin
# 1249  18/01/2021 17:46  33.0   Male       Berlin
# 1250  18/01/2021 23:20  39.0   Male       Munich
# 1251  19/01/2021 10:17  26.0   Male  Saarbrücken
# 1252  19/01/2021 12:01  26.0   Male       Berlin
#
#                                    Position  Total years of experience  \
# 0                          Software Engineer                         5
# 1                          Backend Developer                         7
# 2                          Software Engineer                        12
# 3                         Frontend Developer                         4
# ...

# %%
df_dropped = df.dropna()

# %%
df_dropped
# Out:
#              Timestamp   Age  Gender        City             Position   \
# 35    24/11/2020 11:28  33.0    Male      Berlin        Data Scientist
# 141   24/11/2020 12:09  34.0    Male      Munich       Cloud Architect
# 221   24/11/2020 13:33  32.0    Male   Stuttgart           QA Engineer
# 225   24/11/2020 13:37  24.0    Male  Boeblingen  C/C++/Java developer
# 276   24/11/2020 14:58  38.0    Male      Munich     Backend Developer
# ...                ...   ...     ...         ...                   ...
# 1228  07/01/2021 10:47  28.0    Male      Munich     Software Engineer
# 1233  08/01/2021 17:23  33.0  Female      Munich           Testmanager
# 1236  11/01/2021 12:12  39.0    Male      Berlin           QA Engineer
# 1237  12/01/2021 12:48  37.0    Male      Berlin      Mobile Developer
# 1252  19/01/2021 12:01  26.0    Male      Berlin                DevOps
#
#      Total years of experience Years of experience in Germany Seniority level  \
# ...

# %%
#first set of analysis using corelation

# %%
df_dropped.isnull().sum()
# Out:
# Timestamp                                                                                                                  0
# Age                                                                                                                        0
# Gender                                                                                                                     0
# City                                                                                                                       0
# Position                                                                                                                   0
# Total years of experience                                                                                                  0
# Years of experience in Germany                                                                                             0
# ...

# %%
corelation = df_dropped.corr()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_5228\3303441424.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corelation = df_dropped.corr()

# %%
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns,annot=True)
# Out:
# <Axes: >

# %%
#pairplot

# %%
sns.pairplot(df_dropped)

# %%
#relation plot

# %%
df_dropped.head()

# %%
import seaborn as sns

# %% [markdown]
# most of the full time employees are those who are below fourty years of age

# %%
sns.relplot(x='Age', y='Employment status', data=df_dropped)
# Out:
# c:\Users\hp\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)

# %%
#histogram

# %% [markdown]
# the experience distribution in IT is between zero to five years of age

# %%
sns.distplot(df_dropped['Years of experience in Germany'])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_5228\30864091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_dropped['Years of experience in Germany'])
# <Axes: xlabel='Years of experience in Germany', ylabel='Density'>

# %%
#check on age distribution by employment status in IT jobs

# %%
sns.displot(df_dropped, x="Age", hue="Employment status",multiple="dodge")

# %%
sns.distplot(df_dropped['Age'])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11188\447768496.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_dropped['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
df_dropped.head()
# Out:
#             Timestamp   Age Gender        City             Position   \
# 35   24/11/2020 11:28  33.0   Male      Berlin        Data Scientist
# 141  24/11/2020 12:09  34.0   Male      Munich       Cloud Architect
# 221  24/11/2020 13:33  32.0   Male   Stuttgart           QA Engineer
# 225  24/11/2020 13:37  24.0   Male  Boeblingen  C/C++/Java developer
# 276  24/11/2020 14:58  38.0   Male      Munich     Backend Developer
#
#     Total years of experience Years of experience in Germany Seniority level  \
# 35                          5                              4            Lead
# 141                        10                              4          Senior
# 221                         9                              9          Senior
# 225                       0.8                            0.8          Junior
# 276                        12                             12          Senior
#
#     Your main technology / programming language  \
# ...

# %%
sns.scatterplot(x="Age",y="Employment status",data=df_dropped,hue="City")

# %% [markdown]
# it's clear that 35 years old IT specialists prefer self employment over full time employment.

# %%
sns.barplot(x="Age",y="Employment status",data=df_dropped)
# Out:
# <Axes: xlabel='Age', ylabel='Employment status'>

# %%
#want to check out if year of experience affects the duration of a contract

# %%
df_dropped.head()
# Out:
#             Timestamp   Age Gender        City             Position   \
# 35   24/11/2020 11:28  33.0   Male      Berlin        Data Scientist
# 141  24/11/2020 12:09  34.0   Male      Munich       Cloud Architect
# 221  24/11/2020 13:33  32.0   Male   Stuttgart           QA Engineer
# 225  24/11/2020 13:37  24.0   Male  Boeblingen  C/C++/Java developer
# 276  24/11/2020 14:58  38.0   Male      Munich     Backend Developer
#
#     Total years of experience Years of experience in Germany Seniority level  \
# 35                          5                              4            Lead
# 141                        10                              4          Senior
# 221                         9                              9          Senior
# 225                       0.8                            0.8          Junior
# 276                        12                             12          Senior
#
#     Your main technology / programming language  \
# ...

# %%
sns.relplot(x='Сontract duration', y='Years of experience in Germany', data=df_dropped)

# %%
sns.pairplot(df_dropped)

# %% [markdown]
# it appears that in Germany for an IT in his 40's gets more vacati0n than the younger specialists

# %%
sns.barplot(x="Age",y="Number of vacation days",data=df_dropped)
# Out:
# <Axes: xlabel='Age', ylabel='Number of vacation days'>
